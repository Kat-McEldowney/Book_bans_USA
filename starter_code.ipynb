# %% [markdown]
# # Data Engineering

# %%
# set up
import pandas as pd
import requests
import json
import os

# %% [markdown]
# ## PEN America's Index of School Book Bans Data

# %%
# read in the csv file of banned books from 7/1/2021-6/30/2022
index1 = pd.read_csv('pen_index_book_bans_01JUL2021-30JUN2022.csv', skiprows=2)
index1.head(10)
# Out:
#                    Author                                              Title  \
# 0  Àbíké-Íyímídé, Faridah                                      Ace of Spades
# 1      Acevedo, Elizabeth                                 Clap When You Land
# 2      Acevedo, Elizabeth                                         The Poet X
# 3      Acevedo, Elizabeth                                         The Poet X
# 4      Acevedo, Elizabeth                                         The Poet X
# 5      Acevedo, Elizabeth                                         The Poet X
# 6           Aciman, André  Call Me By Your Name (Call Me By Your Name Ser...
# 7             Acito, Marc  How I Paid for College: A Novel of Sex, Theft,...
# 8          Ada, Alma Flor                            My Name Is María Isabel
# 9            Addasi, Maha                                       Time to Pray
#
#                           Type of Ban Secondary Author(s)  \
# 0  Banned in Libraries and Classrooms                 NaN
# 1                Banned in Classrooms                 NaN
# 2                 Banned in Libraries                 NaN
# 3  Banned in Libraries and Classrooms                 NaN
# 4        Banned Pending Investigation                 NaN
# 5                 Banned in Libraries                 NaN
# 6        Banned Pending Investigation                 NaN
# 7        Banned Pending Investigation                 NaN
# 8        Banned Pending Investigation                 NaN
# 9        Banned Pending Investigation                 NaN
#
#             Illustrator(s)  Translator(s)         State  \
# 0                      NaN            NaN       Florida
# 1                      NaN            NaN  Pennsylvania
# 2                      NaN            NaN       Florida
# 3                      NaN            NaN      New York
# 4                      NaN            NaN         Texas
# 5                      NaN            NaN      Virginia
# 6                      NaN            NaN      Virginia
# 7                      NaN            NaN       Florida
# 8  Thompson, Kathryn Dyble  Cerro, Ana M.       Florida
# 9              Gannon, Ned  Albitar, Nuha       Florida
#
#                                      District Date of Challenge/Removal  \
# 0         Indian River County School District             November 2021
# 1                Central York School District               August 2021
# 2         Indian River County School District             November 2021
# 3            Marlboro Central School District             February 2022
# 4  Fredericksburg Independent School District                March 2022
# 5              New Kent County Public Schools              October 2021
# 6          Spotsylvania County Public Schools             November 2021
# 7         Indian River County School District             November 2021
# 8                 Duval County Public Schools              January 2022
# 9                 Duval County Public Schools              January 2022
#
#   Origin of Challenge
# 0       Administrator
# 1       Administrator
# 2       Administrator
# 3       Administrator
# 4       Administrator
# 5       Administrator
# 6       Administrator
# 7       Administrator
# 8       Administrator
# 9       Administrator

# %%
print("The first index dataframe has {} rows and {} columns".format(index1.shape[0], index1.shape[1]))
# Out:
# The first index dataframe has 2532 rows and 10 columns

# %%
# number of unique titles in the first index
index1['Title'].nunique()
# Out:
# 1648

# %%
# explore the types of book bans in the first index
unique_types_1 = set(index1['Type of Ban'])
print(unique_types_1)
# Out:
# {'Banned in Libraries', 'Banned in Libraries and Classrooms', 'Banned in Classrooms', 'Banned Pending Investigation'}

# %%
# read in the csv file of banned books from 7/1/2022-12/31/2022
index2 = pd.read_csv('pen_index_book_bans_01JUL2022-31DEC2022.csv', skiprows=2)
index2.head(10)
# Out:
#                                                Title            Author  \
# 0        Beyond Magenta: Transgender Teens Speak Out     Kuklin, Susan
# 1                                   Felix Ever After  Callender, Kacen
# 2                                   This Book Is Gay      Dawson, Juno
# 3                                             Flamer      Curato, Mike
# 4                             Gender Queer: A Memoir      Kobabe, Maia
# 5  Let's Talk About It: The Teen's Guide to Sex, ...       Moen, Erika
# 6                           A Court of Mist and Fury    Maas, Sarah J.
# 7                                              Crank    Hopkins, Ellen
# 8                                   Empire of Storms    Maas, Sarah J.
# 9                           House of Earth and Blood    Maas, Sarah J.
#
#   Secondary Author(s) Illustrator(s) Translator(s)  \
# 0                 NaN            NaN           NaN
# 1                 NaN            NaN           NaN
# 2                 NaN            NaN           NaN
# 3                 NaN            NaN           NaN
# 4                 NaN            NaN           NaN
# 5      Nolan, Matthew            NaN           NaN
# 6                 NaN            NaN           NaN
# 7                 NaN            NaN           NaN
# 8                 NaN            NaN           NaN
# 9                 NaN            NaN           NaN
#
#                    Series Name       State  \
# 0                          NaN    Arkansas
# 1                          NaN    Arkansas
# 2                          NaN  California
# 3                          NaN    Colorado
# 4                          NaN    Colorado
# 5                          NaN    Colorado
# 6  A Court of Thorns and Roses     Florida
# 7                        Crank     Florida
# 8              Throne of Glass     Florida
# 9                Crescent City     Florida
#
#                                      District Date of Challenge/Removal  \
# 0                       Conway Public Schools              October 2022
# 1                       Conway Public Schools              October 2022
# 2  William S. Hart Union High School District            September 2022
# 3                Cherry Creek School District            September 2022
# 4                Cherry Creek School District            September 2022
# 5                Cherry Creek School District            September 2022
# 6                             Brevard Schools             November 2022
# 7                             Brevard Schools             November 2022
# 8                             Brevard Schools             November 2022
# 9                             Brevard Schools             November 2022
#
#                            Ban Status Origin of Challenge
# 0  Banned in Libraries and Classrooms             Unclear
# 1  Banned in Libraries and Classrooms             Unclear
# 2  Banned in Libraries and Classrooms             Unclear
# 3        Banned Pending Investigation             Unclear
# 4        Banned Pending Investigation             Unclear
# 5  Banned in Libraries and Classrooms             Unclear
# 6        Banned Pending Investigation    Formal Challenge
# 7        Banned Pending Investigation    Formal Challenge
# 8        Banned Pending Investigation    Formal Challenge
# 9        Banned Pending Investigation    Formal Challenge

# %%
print("The second index dataframe has {} rows and {} columns".format(index2.shape[0], index2.shape[1]))
# Out:
# The second index dataframe has 1477 rows and 11 columns

# %%
# number of unique titles in the second index
index2['Title'].nunique()
# Out:
# 873

# %%
# explore the types of book bans in the second index
unique_types_2 = set(index2['Ban Status'])
print(unique_types_2)
# Out:
# {'Banned Pending Investigation', 'Banned in Libraries and Classrooms', 'Banned in Classrooms', 'Banned in Libraries'}

# %%
# rename the ban status column as type of ban
index2.rename(columns={'Ban Status': 'Type of Ban'}, inplace = True)
index2.head()
# Out:
#                                          Title            Author  \
# 0  Beyond Magenta: Transgender Teens Speak Out     Kuklin, Susan
# 1                             Felix Ever After  Callender, Kacen
# 2                             This Book Is Gay      Dawson, Juno
# 3                                       Flamer      Curato, Mike
# 4                       Gender Queer: A Memoir      Kobabe, Maia
#
#   Secondary Author(s) Illustrator(s) Translator(s) Series Name       State  \
# 0                 NaN            NaN           NaN         NaN    Arkansas
# 1                 NaN            NaN           NaN         NaN    Arkansas
# 2                 NaN            NaN           NaN         NaN  California
# 3                 NaN            NaN           NaN         NaN    Colorado
# 4                 NaN            NaN           NaN         NaN    Colorado
#
#                                      District Date of Challenge/Removal  \
# 0                       Conway Public Schools              October 2022
# 1                       Conway Public Schools              October 2022
# 2  William S. Hart Union High School District            September 2022
# 3                Cherry Creek School District            September 2022
# 4                Cherry Creek School District            September 2022
#
#                           Type of Ban Origin of Challenge
# 0  Banned in Libraries and Classrooms             Unclear
# 1  Banned in Libraries and Classrooms             Unclear
# 2  Banned in Libraries and Classrooms             Unclear
# 3        Banned Pending Investigation             Unclear
# 4        Banned Pending Investigation             Unclear

# %%
# drop the series name column in the second index dataset
index2.drop(['Series Name'], axis=1, inplace=True)
index2.head()
# Out:
#                                          Title            Author  \
# 0  Beyond Magenta: Transgender Teens Speak Out     Kuklin, Susan
# 1                             Felix Ever After  Callender, Kacen
# 2                             This Book Is Gay      Dawson, Juno
# 3                                       Flamer      Curato, Mike
# 4                       Gender Queer: A Memoir      Kobabe, Maia
#
#   Secondary Author(s) Illustrator(s) Translator(s)       State  \
# 0                 NaN            NaN           NaN    Arkansas
# 1                 NaN            NaN           NaN    Arkansas
# 2                 NaN            NaN           NaN  California
# 3                 NaN            NaN           NaN    Colorado
# 4                 NaN            NaN           NaN    Colorado
#
#                                      District Date of Challenge/Removal  \
# 0                       Conway Public Schools              October 2022
# 1                       Conway Public Schools              October 2022
# 2  William S. Hart Union High School District            September 2022
# 3                Cherry Creek School District            September 2022
# 4                Cherry Creek School District            September 2022
#
#                           Type of Ban Origin of Challenge
# 0  Banned in Libraries and Classrooms             Unclear
# 1  Banned in Libraries and Classrooms             Unclear
# 2  Banned in Libraries and Classrooms             Unclear
# 3        Banned Pending Investigation             Unclear
# 4        Banned Pending Investigation             Unclear

# %%
# consolidate the two dataframes into one
combined = pd.concat([index1, index2], ignore_index=True)
combined.tail()
# Out:
#                        Author  \
# 4004              Lyga, Barry
# 4005         Arnold, Elana K.
# 4006         McQuiston, Casey
# 4007             Kobabe, Maia
# 4008  Erickson-Schroth, Laura
#
#                                                   Title  \
# 4004                                            Boy Toy
# 4005                                           Red Hood
# 4006                         Red, White, and Royal Blue
# 4007                             Gender Queer: A Memoir
# 4008  Trans Bodies, Trans Selves: A Resource By and ...
#
#                              Type of Ban Secondary Author(s) Illustrator(s)  \
# 4004  Banned in Libraries and Classrooms                 NaN            NaN
# 4005  Banned in Libraries and Classrooms                 NaN            NaN
# 4006  Banned in Libraries and Classrooms                 NaN            NaN
# 4007        Banned Pending Investigation                 NaN            NaN
# 4008        Banned Pending Investigation                 NaN            NaN
#
#      Translator(s)     State                            District  \
# 4004           NaN  Virginia  Spotsylvania County Public Schools
# 4005           NaN  Virginia  Spotsylvania County Public Schools
# 4006           NaN  Virginia  Spotsylvania County Public Schools
# 4007           NaN   Wyoming              Natrona County Schools
# 4008           NaN   Wyoming              Natrona County Schools
#
#      Date of Challenge/Removal Origin of Challenge
# 4004              October 2022    Formal Challenge
# 4005              October 2022    Formal Challenge
# 4006              October 2022    Formal Challenge
# 4007              October 2022    Formal Challenge
# 4008              October 2022    Formal Challenge

# %%
print("The combined dataframe has {} rows and {} columns".format(combined.shape[0], combined.shape[1]))
# Out:
# The combined dataframe has 4009 rows and 10 columns

# %%
# drop columns that we are not interested in for this project
combined = combined[['Title', 'Author', 'Type of Ban', 'State', 'District', 'Date of Challenge/Removal']]
combined
# Out:
#                                                   Title  \
# 0                                         Ace of Spades
# 1                                    Clap When You Land
# 2                                            The Poet X
# 3                                            The Poet X
# 4                                            The Poet X
# ...                                                 ...
# 4004                                            Boy Toy
# 4005                                           Red Hood
# 4006                         Red, White, and Royal Blue
# 4007                             Gender Queer: A Memoir
# 4008  Trans Bodies, Trans Selves: A Resource By and ...
#
#                        Author                         Type of Ban  \
# 0      Àbíké-Íyímídé, Faridah  Banned in Libraries and Classrooms
# 1          Acevedo, Elizabeth                Banned in Classrooms
# 2          Acevedo, Elizabeth                 Banned in Libraries
# 3          Acevedo, Elizabeth  Banned in Libraries and Classrooms
# 4          Acevedo, Elizabeth        Banned Pending Investigation
# ...                       ...                                 ...
# 4004              Lyga, Barry  Banned in Libraries and Classrooms
# 4005         Arnold, Elana K.  Banned in Libraries and Classrooms
# 4006         McQuiston, Casey  Banned in Libraries and Classrooms
# 4007             Kobabe, Maia        Banned Pending Investigation
# 4008  Erickson-Schroth, Laura        Banned Pending Investigation
#
#              State                                    District  \
# 0          Florida         Indian River County School District
# 1     Pennsylvania                Central York School District
# 2          Florida         Indian River County School District
# 3         New York            Marlboro Central School District
# 4            Texas  Fredericksburg Independent School District
# ...            ...                                         ...
# 4004      Virginia          Spotsylvania County Public Schools
# 4005      Virginia          Spotsylvania County Public Schools
# 4006      Virginia          Spotsylvania County Public Schools
# 4007       Wyoming                      Natrona County Schools
# 4008       Wyoming                      Natrona County Schools
#
#      Date of Challenge/Removal
# 0                November 2021
# 1                  August 2021
# 2                November 2021
# 3                February 2022
# 4                   March 2022
# ...                        ...
# 4004              October 2022
# 4005              October 2022
# 4006              October 2022
# 4007              October 2022
# 4008              October 2022
#
# [4009 rows x 6 columns]

# %%
# group the dataframe by type of ban
combined_grouped = combined.groupby(['Title', 'State', 'Type of Ban']).size().reset_index(name='Count')
combined_grouped
# Out:
#                                                   Title           State  \
# 0     "Multiplication Is for White People": Raising ...    Pennsylvania
# 1                  #BlackLivesMatter: Protesting Racism         Florida
# 2                  #BlackLivesMatter: Protesting Racism           Texas
# 3                                               #Hockey           Texas
# 4                       #Hockey (Check, Please! Series)         Georgia
# ...                                                 ...             ...
# 3479                                               yolo  South Carolina
# 3480                       yolo (Internet Girls Series)       Wisconsin
# 3481  ¡Solo pregunta!: Sé Diferente, Sé Valiente, Sé Tú    Pennsylvania
# 3482                                ¡Vámonos! Let's Go!    Pennsylvania
# 3483                ¿De Dónde Eres?/Where Are You From?    Pennsylvania
#
#                              Type of Ban  Count
# 0                   Banned in Classrooms      1
# 1           Banned Pending Investigation      1
# 2           Banned Pending Investigation      1
# 3     Banned in Libraries and Classrooms      1
# 4     Banned in Libraries and Classrooms      1
# ...                                  ...    ...
# 3479        Banned Pending Investigation      1
# 3480                 Banned in Libraries      1
# 3481                Banned in Classrooms      1
# 3482                Banned in Classrooms      1
# 3483                Banned in Classrooms      1
#
# [3484 rows x 4 columns]

# %%
# introduce a list of 13 most banned books from the american library association (ALA)
most_banned_13 = ["Gender Queer: A Memoir", "All Boys Aren't Blue", "The Bluest Eye", "Flamer", 
                  "Looking For Alaska", "The Perks of Being a Wallflower", "Lawn Boy", 
                  "The Absolutely True Diary of a Part-Time Indian", "Out of Darkness",
                 "A Court of Mist and Fury", "Crank", "Me and Earl and the Dying Girl", 
                  "This Book is Gay"]

# %%
# subset the dataframe to 13 most banned
combined_most_banned = combined_grouped[combined_grouped["Title"].isin(most_banned_13)].sort_values(by='State')
combined_most_banned
# Out:
#                          Title       State  \
# 1005    Gender Queer: A Memoir      Alaska
# 900                     Flamer    Colorado
# 1006    Gender Queer: A Memoir    Colorado
# 58    A Court of Mist and Fury     Florida
# 623                      Crank     Florida
# ...                        ...         ...
# 198       All Boys Aren't Blue  Washington
# 1036    Gender Queer: A Memoir  Washington
# 1961           Out of Darkness   Wisconsin
# 914                     Flamer   Wisconsin
# 1037    Gender Queer: A Memoir     Wyoming
#
#                              Type of Ban  Count
# 1005  Banned in Libraries and Classrooms      1
# 900         Banned Pending Investigation      1
# 1006        Banned Pending Investigation      1
# 58          Banned Pending Investigation      3
# 623                  Banned in Libraries      1
# ...                                  ...    ...
# 198         Banned Pending Investigation      1
# 1036        Banned Pending Investigation      2
# 1961                 Banned in Libraries      1
# 914   Banned in Libraries and Classrooms      1
# 1037        Banned Pending Investigation      1
#
# [183 rows x 4 columns]

# %%
# convert and save the dataframe as json
combined_most_banned.to_json('pen_13_most_banned.json', orient = 'records')

# %% [markdown]
# ## Open Library Data

# %%
# get request to open library api to see how the data is formatted
url = "http://openlibrary.org/search.json?q=Flamer&limit=1"
response = requests.get(url)
# print(response.json())
# Out:
# {'numFound': 16, 'start': 0, 'numFoundExact': True, 'docs': [{'key': '/works/OL20813470W', 'type': 'work', 'seed': ['/books/OL28348427M', '/books/OL28177022M', '/works/OL20813470W', '/subjects/lgbtq_young_adult', '/subjects/lambda_literary_awards', '/subjects/lambda_literary_award_winner', '/subjects/collectionid:texchallenge2021', '/subjects/collectionid:kellerchallenge', '/subjects/collectionid:alpinechallenge', '/subjects/comic_books_strips', '/subjects/juvenile_fiction', '/subjects/fiction', '/subjects/coming_out_(sexual_orientation)', '/subjects/camps', '/subjects/gay_teenagers', '/subjects/closeted_gays', '/subjects/infatuation', '/subjects/bullying', '/subjects/teenagers', '/subjects/suicidal_behavior', '/subjects/identity_(psychology)', '/subjects/self', '/subjects/catholic_church', '/subjects/sortir_du_placard_(homosexualité)', '/subjects/bandes_dessinées', '/subjects/romans_nouvelles_etc._pour_la_jeunesse', '/subjects/colonies_de_vacances', '/subjects/adolescents_homosexuels', '/subjects/homosexuels_dans_le_placard', '/subjects/intimidation', '/subjects/adolescents', '/subjects/comportement_suicidaire', '/subjects/identité_(psychologie)', '/subjects/moi_(psychologie)', '/subjects/aspect_religieux', '/subjects/église_catholique', '/subjects/asian_american_lgbtq+_people', '/subjects/boy_scouts_of_america', '/authors/OL7413184A'], 'title': 'Flamer', 'title_sort': 'Flamer', 'title_suggest': 'Flamer', 'edition_count': 2, 'edition_key': ['OL28348427M', 'OL28177022M'], 'publish_date': ['Sep 01, 2020'], 'publish_year': [2020], 'first_publish_year': 2020, 'number_of_pages_median': 368, 'oclc': ['1123238947'], 'lcc': ['PN-6727.00000000.C86 F53 2020', 'PZ-0007.70000000.C875 Fl 2020'], 'isbn': ['9781250756145', '9781627796415', '162779641X', '1250756146'], 'last_modified_i': 1693764921, 'ebook_count_i': 0, 'ebook_access': 'no_ebook', 'has_fulltext': False, 'public_scan_b': False, 'ratings_average': 3.3333333, 'ratings_sortable': 2.280186, 'ratings_count': 3, 'ratings_count_1': 1, 'ratings_count_2': 0, 'ratings_count_3': 0, 'ratings_count_4': 1, 'ratings_count_5': 1, 'readinglog_count': 35, 'want_to_read_count': 31, 'currently_reading_count': 3, 'already_read_count': 1, 'cover_edition_key': 'OL28177022M', 'cover_i': 10114290, 'publisher': ['Henry Holt and Co. (BYR)', 'Henry Holt and Co. BYR Paperbacks'], 'author_key': ['OL7413184A'], 'author_name': ['Mike Curato'], 'subject': ['LGBTQ young adult', 'Lambda Literary Awards', 'Lambda Literary Award Winner', 'collectionID:TexChallenge2021', 'collectionID:KellerChallenge', 'collectionID:AlpineChallenge', 'Comic books, strips', 'Juvenile fiction', 'Fiction', 'Coming out (Sexual orientation)', 'Camps', 'Gay teenagers', 'Closeted gays', 'Infatuation', 'Bullying', 'Teenagers', 'Suicidal behavior', 'Identity (Psychology)', 'Self', 'Catholic Church', 'Sortir du placard (Homosexualité)', 'Bandes dessinées', 'Romans, nouvelles, etc. pour la jeunesse', 'Colonies de vacances', 'Adolescents homosexuels', 'Homosexuels dans le placard', 'Intimidation', 'Adolescents', 'Comportement suicidaire', 'Identité (Psychologie)', 'Moi (Psychologie)', 'Aspect religieux', 'Église catholique', 'Asian American LGBTQ+ people', 'Boy Scouts of America'], 'id_wikidata': ['Q118109607', 'Q118109596'], 'publisher_facet': ['Henry Holt and Co. (BYR)', 'Henry Holt and Co. BYR Paperbacks'], 'subject_facet': ['Adolescents', 'Adolescents homosexuels', 'Asian American LGBTQ+ people', 'Aspect religieux', 'Bandes dessinées', 'Boy Scouts of America', 'Bullying', 'Camps', 'Catholic Church', 'Closeted gays', 'Colonies de vacances', 'Comic books, strips', 'Coming out (Sexual orientation)', 'Comportement suicidaire', 'Fiction', 'Gay teenagers', 'Homosexuels dans le placard', 'Identity (Psychology)', 'Identité (Psychologie)', 'Infatuation', 'Intimidation', 'Juvenile fiction', 'LGBTQ young adult', 'Lambda Literary Award Winner', 'Lambda Literary Awards', 'Moi (Psychologie)', 'Romans, nouvelles, etc. pour la jeunesse', 'Self', 'Sortir  ...

# %%
# api call to open library to get book jacket images
def get_jacket_art(title):
    url = f"http://openlibrary.org/search.json?q={title}&limit=1"
    response=requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data['docs']:
            cover_id = data['docs'][0]['cover_i']
            if cover_id:
                cover_query = f"http://covers.openlibrary.org/b/id/{cover_id}-L.jpg"
                cover_image = requests.get(cover_query).content
                with open(os.path.join("cover_images", f"{title}_cover.jpg"), 'wb') as c:
                    c.write(cover_image)
                print(f"Cover art for {title} saved as {title}_cover.jpg")
            else:
                print(f"No cover art found for {title}")
        else:
            print(f"{title} not found in Open Library")
    else:
        print('API call failed, try again')

for title in most_banned_13:
    get_jacket_art(title)
# Out:
# Cover art for Gender Queer: A Memoir saved as Gender Queer: A Memoir_cover.jpg
# Cover art for All Boys Aren't Blue saved as All Boys Aren't Blue_cover.jpg
# Cover art for The Bluest Eye saved as The Bluest Eye_cover.jpg
# Cover art for Flamer saved as Flamer_cover.jpg
# Cover art for Looking For Alaska saved as Looking For Alaska_cover.jpg
# Cover art for The Perks of Being a Wallflower saved as The Perks of Being a Wallflower_cover.jpg
# Cover art for Lawn Boy saved as Lawn Boy_cover.jpg
# Cover art for The Absolutely True Diary of a Part-Time Indian saved as The Absolutely True Diary of a Part-Time Indian_cover.jpg
# Cover art for Out of Darkness saved as Out of Darkness_cover.jpg
# Cover art for A Court of Mist and Fury saved as A Court of Mist and Fury_cover.jpg
# Cover art for Crank saved as Crank_cover.jpg
# Cover art for Me and Earl and the Dying Girl saved as Me and Earl and the Dying Girl_cover.jpg
# Cover art for This Book is Gay saved as This Book is Gay_cover.jpg

# %%
# use open library to get data on books
book_info_dict = {}

def get_book_info(title):
    url = f"http://openlibrary.org/search.json?q={title}&limit=1"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data['docs']:
            book_info_dict[title] = {
                'title': data['docs'][0]['title'],
                'author': data['docs'][0]['author_name'][0] if 'author_name' in data['docs'][0] else None,
                'publisher': data['docs'][0]['publisher'][0] if 'publisher' in data['docs'][0] else None,
                'publish_date': data['docs'][0]['first_publish_year'] if 'first_publish_year' in data['docs'][0] else None
            }
        else:
            print(f"{title} not found in Open Library")
    else:
        print("API call failed, try again")
        

for title in most_banned_13:
    get_book_info(title)

# Save all book information as a single JSON file
with open("book_info.json", 'w') as f:
    json.dump(book_info_dict, f, indent=4)

print("All book information saved as 'all_books_info.json'")
# Out:
# All book information saved as 'all_books_info.json'
