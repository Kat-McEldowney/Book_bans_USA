# %%
import pandas as pd

# %%
# read the CSVs
index_1 = 'PEN_Ams_Index_07_01_21_to_06_30_22.csv'
index_2 = 'PEN_Ams_Index_07_01_22_to_06_30_23.csv'

# Read CSV files into pandas DataFrames
df1 = pd.read_csv(index_1, skiprows =2)
df1.head()
# Out:
#                    Author               Title  \
# 0  Àbíké-Íyímídé, Faridah       Ace of Spades
# 1      Acevedo, Elizabeth  Clap When You Land
# 2      Acevedo, Elizabeth          The Poet X
# 3      Acevedo, Elizabeth          The Poet X
# 4      Acevedo, Elizabeth          The Poet X
#
#                           Type of Ban Secondary Author(s) Illustrator(s)  \
# 0  Banned in Libraries and Classrooms                 NaN            NaN
# 1                Banned in Classrooms                 NaN            NaN
# 2                 Banned in Libraries                 NaN            NaN
# 3  Banned in Libraries and Classrooms                 NaN            NaN
# 4        Banned Pending Investigation                 NaN            NaN
#
#   Translator(s)         State                                    District  \
# 0           NaN       Florida         Indian River County School District
# 1           NaN  Pennsylvania                Central York School District
# 2           NaN       Florida         Indian River County School District
# 3           NaN      New York            Marlboro Central School District
# 4           NaN         Texas  Fredericksburg Independent School District
#
#   Date of Challenge/Removal Origin of Challenge
# 0             November 2021       Administrator
# 1               August 2021       Administrator
# 2             November 2021       Administrator
# 3             February 2022       Administrator
# 4                March 2022       Administrator

# %%
#create the 2nd DF with column names
columns = ['Title', 'Author', 'Secondary Author', 'Illustrators(s)', 'Translatror(s)', 
           'Series Name', 'State', 'District', 'Date of Challenge', 'Ban Status', 'Origin of Challenge']
df2 = pd.read_csv(index_2, header=None)
df2.columns = columns

df2.head()
# Out:
#                     Title          Author Secondary Author Illustrators(s)  \
# 0        This Book Is Gay    Dawson, Juno              NaN             NaN
# 1               Identical  Hopkins, Ellen              NaN             NaN
# 2                   Lucky   Sebold, Alice              NaN             NaN
# 3                    Push        Sapphire              NaN             NaN
# 4  Gender Queer: A Memoir    Kobabe, Maia              NaN             NaN
#
#   Translatror(s) Series Name           State  \
# 0            NaN         NaN   Massachusetts
# 1            NaN         NaN        Colorado
# 2            NaN         NaN        Colorado
# 3            NaN         NaN        Colorado
# 4            NaN         NaN  North Carolina
#
#                               District Date of Challenge  \
# 0              Abington Public Schools      October 2022
# 1           Academy School District 20          May 2023
# 2           Academy School District 20          May 2023
# 3           Academy School District 20          May 2023
# 4  Alamance-Burlington School District    September 2022
#
#                              Ban Status Origin of Challenge
# 0          Banned Pending Investigation    Formal Challenge
# 1          Banned Pending Investigation  Informal Challenge
# 2          Banned Pending Investigation  Informal Challenge
# 3          Banned Pending Investigation  Informal Challenge
# 4  Banned from Libraries and Classrooms  Informal Challenge

# %%
# # Concatenate the DataFrames
# combined_df = pd.concat([df1, df2], ignore_index=True)

# # Display the concatenated DataFrame
# combined_df.head()

# %%
most_banned_13 = ["Gender Queer: A Memoir", "All Boys Aren't Blue", "The Bluest Eye", "Flamer", 
                  "Looking For Alaska", "The Perks of Being a Wallflower", "Lawn Boy", 
                  "The Absoutely True Diary of a Part-Time Indian", "Out of Darkness",
                 "A Court of Mist and Fury", "Crank", "Me and Earl and the Dying Girl", 
                  "This Book is Gay"]

# %%
df1_filtered = df1[df1["Title"].isin(most_banned_13)]
df1_filtered.shape
# Out:
# (165, 10)
